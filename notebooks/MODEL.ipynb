# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('../data/Algerian_forest_fire_cleaned_dataset.csv')

# %%
df.head()
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI      Classes  Region
# 0  0.5  not fire          0
# 1  0.4  not fire          0
# 2  0.1  not fire          0
# 3  0.0  not fire          0
# 4  0.5  not fire          0

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='object')

# %%
df.drop(['day','month','year'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI      Classes  \
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5  not fire
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4  not fire
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1  not fire
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0  not fire
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5  not fire
#
#    Region
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
df['Classes'].value_counts()
# Out:
# Classes
# fire             131
# not fire         101
# fire               4
# fire               2
# not fire           2
# not fire           1
# not fire           1
# not fire           1
# Name: count, dtype: int64

# %%
df['Classes']=np.where(df['Classes'].str.contains('not fire'),0,1)

# %%
df.tail()
# Out:
#      Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  FWI  Classes  \
# 238           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9  6.5        1
# 239           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2  0.0        0
# 240           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4  0.2        0
# 241           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1  0.7        0
# 242           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8  0.5        0
#
#      Region
# 238       1
# 239       1
# 240       1
# 241       1
# 242       1

# %%
df['ISI'].max()
# Out:
# np.float64(19.0)

# %%
df['Classes'].value_counts()
# Out:
# Classes
# 1    137
# 0    106
# Name: count, dtype: int64

# %%
x=df.drop('FWI',axis=1)
y=df['FWI']

# %%
x.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  Classes  Region
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4        0       0
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9        0       0
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7        0       0
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7        0       0
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9        0       0

# %%
y
# Out:
# 0      0.5
# 1      0.4
# 2      0.1
# 3      0.0
# 4      0.5
#       ...
# 238    6.5
# 239    0.0
# 240    0.2
# 241    0.7
# 242    0.5
# Name: FWI, Length: 243, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)

# %%
x_train.shape,x_test.shape
# Out:
# ((182, 11), (61, 11))

# %%
x_train.corr()
# Out:
#              Temperature        RH        Ws      Rain      FFMC       DMC  \
# Temperature     1.000000 -0.656095 -0.305977 -0.317512  0.694768  0.498173
# RH             -0.656095  1.000000  0.225736  0.241656 -0.653023 -0.414601
# Ws             -0.305977  0.225736  1.000000  0.251932 -0.190076  0.000379
# Rain           -0.317512  0.241656  0.251932  1.000000 -0.545491 -0.289754
# FFMC            0.694768 -0.653023 -0.190076 -0.545491  1.000000  0.620807
# DMC             0.498173 -0.414601  0.000379 -0.289754  0.620807  1.000000
# DC              0.390684 -0.236078  0.096576 -0.302341  0.524101  0.868647
# ISI             0.629848 -0.717804 -0.023558 -0.345707  0.750799  0.685656
# BUI             0.473609 -0.362317  0.035633 -0.300964  0.607210  0.983175
# Classes         0.542141 -0.456876 -0.082570 -0.369357  0.781259  0.617273
# Region          0.254549 -0.394665 -0.199969 -0.059022  0.249514  0.212582
#
#                    DC       ISI       BUI   Classes    Region
# ...

# %%
plt.figure(figsize=(12,10))
corr=x_train.corr()
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
x_train.corr()
# Out:
#              Temperature        RH        Ws      Rain      FFMC       DMC  \
# Temperature     1.000000 -0.656095 -0.305977 -0.317512  0.694768  0.498173
# RH             -0.656095  1.000000  0.225736  0.241656 -0.653023 -0.414601
# Ws             -0.305977  0.225736  1.000000  0.251932 -0.190076  0.000379
# Rain           -0.317512  0.241656  0.251932  1.000000 -0.545491 -0.289754
# FFMC            0.694768 -0.653023 -0.190076 -0.545491  1.000000  0.620807
# DMC             0.498173 -0.414601  0.000379 -0.289754  0.620807  1.000000
# DC              0.390684 -0.236078  0.096576 -0.302341  0.524101  0.868647
# ISI             0.629848 -0.717804 -0.023558 -0.345707  0.750799  0.685656
# BUI             0.473609 -0.362317  0.035633 -0.300964  0.607210  0.983175
# Classes         0.542141 -0.456876 -0.082570 -0.369357  0.781259  0.617273
# Region          0.254549 -0.394665 -0.199969 -0.059022  0.249514  0.212582
#
#                    DC       ISI       BUI   Classes    Region
# ...

# %%
def correlation(dataset,threshold):
    col_corr=set()
    corr_matrix=dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i,j])>threshold:
                colname=corr_matrix.columns[i]
                col_corr.add(colname)
    return col_corr

# %%
corr_features=correlation(x_train,0.85)

# %%
corr_features
# Out:
# {'BUI', 'DC'}

# %%
x_train.drop(corr_features,axis=1,inplace=True)
x_test.drop(corr_features,axis=1,inplace=True)
x_train.shape,x_test.shape
# Out:
# ((182, 9), (61, 9))

# %% [markdown]
# ## Feature Scaling Or Standardization

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_train_scaled=scaler.fit_transform(x_train)
x_test_scaled=scaler.transform(x_test)

# %%
x_train_scaled
# Out:
# array([[-0.84284248,  0.78307967,  1.29972026, ..., -0.62963326,
#         -1.10431526, -0.98907071],
#        [-0.30175842,  0.64950844, -0.59874754, ..., -0.93058524,
#         -1.10431526,  1.01105006],
#        [ 2.13311985, -2.08870172, -0.21905398, ...,  2.7271388 ,
#          0.90553851,  1.01105006],
#        ...,
#        [-1.9250106 ,  0.9166509 ,  0.54033314, ..., -1.06948615,
#         -1.10431526, -0.98907071],
#        [ 0.50986767, -0.21870454,  0.16063958, ...,  0.5973248 ,
#          0.90553851,  1.01105006],
#        [-0.57230045,  0.98343651,  2.05910739, ..., -0.86113478,
#         -1.10431526, -0.98907071]], shape=(182, 9))

# %% [markdown]
# ## Box Plots To understand Effect Of Standard Scaler

# %%
plt.subplots(figsize=(15,5))
plt.subplot(1,2,1)
sns.boxplot(data=x_train)
plt.subplot(1,2,2)
sns.boxplot(data=x_train_scaled)
plt.title("X_train After Scaling")
plt.show()

# %% [markdown]
# ## Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error

lineareg=LinearRegression()
lineareg.fit(x_train_scaled,y_train)
y_pred_lineareg=lineareg.predict(x_test_scaled)
print("Mean Absolute Error :",mean_absolute_error(y_test,y_pred_lineareg))
print("Mean Squared Error : ",mean_squared_error(y_test,y_pred_lineareg))
print("R2 score is : ",r2_score(y_test,y_pred_lineareg))
plt.scatter(y_test,y_pred_lineareg)
plt.show()
# Out:
# Mean Absolute Error : 0.5468236465249978
# Mean Squared Error :  0.674276687379158
# R2 score is :  0.9847657384266951

# %% [markdown]
# ## Lasso Regression

# %%
from sklearn.linear_model import Lasso
lasso=Lasso()
lasso.fit(x_train_scaled,y_train)
y_pred_lasso=lasso.predict(x_test_scaled)
print("Mean Squared Error : ",mean_squared_error(y_test,y_pred_lasso))
print("Mean Absolute Error : ",mean_absolute_error(y_test,y_pred_lasso))
print("R2 Score : ",r2_score(y_test,y_pred_lasso))
plt.scatter(y_test,y_pred_lasso)
plt.show()
# Out:
# Mean Squared Error :  2.248345891897476
# Mean Absolute Error :  1.1331759949144087
# R2 Score :  0.9492020263112388

# %% [markdown]
# ### Cross Validation Lasso

# %%
from sklearn.linear_model import LassoCV
lassc=LassoCV(cv=5)
lassc.fit(x_train_scaled,y_train)
y_pred_lassocv=lassc.predict(x_test_scaled)
print("Mean Squared Error is : ",mean_squared_error(y_test,y_pred_lassocv))
print("Mean Absolute Error is : ",mean_absolute_error(y_test,y_pred_lassocv))
print("R2 Score : ",r2_score(y_test,y_pred_lassocv))
plt.scatter(y_test,y_pred_lassocv)
plt.show()
# Out:
# Mean Squared Error is :  0.8214458563350046
# Mean Absolute Error is :  0.6358894638564663
# R2 Score :  0.9814406737205228

# %% [markdown]
# ## Ridge Regression model

# %%
from sklearn.linear_model import Ridge
ridge=Ridge()
ridge.fit(x_train_scaled,y_train)
y_pred_ridge=ridge.predict(x_test_scaled)
print("Mean squared Error is : ",mean_squared_error(y_test,y_pred_ridge))
print("Mean Absolute Error is : ",mean_absolute_error(y_test,y_pred_ridge))
print("R2 Score is : ",r2_score(y_test,y_pred_ridge))
plt.scatter(y_test,y_pred_ridge)
# Out:
# Mean squared Error is :  0.6949198918152096
# Mean Absolute Error is :  0.5642305340105715
# R2 Score is :  0.9842993364555512

# %% [markdown]
# ## RidgeCV Regression model

# %%
from sklearn.linear_model import RidgeCV
ridgecv=RidgeCV(cv=5)
ridgecv.fit(x_train_scaled,y_train)
y_pred_ridgecv=ridgecv.predict(x_test_scaled)
print("Mean squared Error is : ",mean_squared_error(y_test,y_pred_ridgecv))
print("Mean Absolute Error is : ",mean_absolute_error(y_test,y_pred_ridgecv))
print("R2 Score is : ",r2_score(y_test,y_pred_ridgecv))
plt.scatter(y_test,y_pred_ridgecv)
plt.show()
# Out:
# Mean squared Error is :  0.6949198918152096
# Mean Absolute Error is :  0.5642305340105715
# R2 Score is :  0.9842993364555512

# %% [markdown]
# ## Elasticnet Regression

# %%
from sklearn.linear_model  import ElasticNet
elastic=ElasticNet()
elastic.fit(x_train_scaled,y_train)
y_pred_elastic=elastic.predict(x_test_scaled)
print("Mean squared Error is : ",mean_squared_error(y_test,y_pred_elastic))
print("Mean Absolute Error is : ",mean_absolute_error(y_test,y_pred_elastic))
print("R2 Score is : ",r2_score(y_test,y_pred_elastic))
plt.scatter(y_test,y_pred_elastic)
plt.show()
# Out:
# Mean squared Error is :  5.517251101025223
# Mean Absolute Error is :  1.8822353634895999
# R2 Score is :  0.8753460589519703

# %%
from sklearn.linear_model  import ElasticNetCV
elasticv=ElasticNetCV(cv=5)
elasticv.fit(x_train_scaled,y_train)
y_pred_elasticv=elasticv.predict(x_test_scaled)
print("Mean squared Error is : ",mean_squared_error(y_test,y_pred_elasticv))
print("Mean Absolute Error is : ",mean_absolute_error(y_test,y_pred_elasticv))
print("R2 Score is : ",r2_score(y_test,y_pred_elasticv))
plt.scatter(y_test,y_pred_elasticv)
plt.show()
# Out:
# Mean squared Error is :  0.8222830416276266
# Mean Absolute Error is :  0.6575946731430901
# R2 Score is :  0.9814217587854941

# %%
import joblib

joblib.dump(lineareg,open('../models/best_linear_regression_model.pkl','wb'))
print("Best Linear Regression Model saved as best_linear_regression_model.pkl")


joblib.dump(scaler,open('../models/scaler.pkl','wb'))
print("standard sscaler is saved as scaler.pkl")
# Out:
# Best Linear Regression Model saved as best_linear_regression_model.pkl
# standard sscaler is saved as scaler.pkl
